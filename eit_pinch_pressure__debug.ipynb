# %%
import glob
import os
import numpy as np
from sklearn.model_selection import train_test_split
is_windowed = True #@param{type: "boolean"}
window_size = 10 #@param
is_normalization = True #@param{type: "boolean"}
def normalize(raw_data):
  mean = np.mean(raw_data, axis=0)
  std = np.std(raw_data, axis=0)
  normalized_data = (raw_data - mean) / (std + 1e-6)
  return normalized_data

# Function to create windowed data
def create_windowed_data(X, y, window_size=10):
    num_samples = X.shape[0] - window_size + 1  # Number of windows we can create
    windowed_X = np.array([(normalize(X[i:i + window_size]) if is_normalization else X[i:i + window_size]) for i in range(num_samples)])
    windowed_y = np.array([np.mean(y[i + window_size - 1]) for i in range(num_samples)])  # target at the end of the window
    # should delete
    # unnormalize_windowed_X = np.array([( X[i:i + window_size]) for i in range(num_samples)])
    # print(windowed_X[2000])
    # print(unnormalize_windowed_X[2000])
    return windowed_X, windowed_y

def load_and_preprocess_data(data_path):
    data = None
    labels = None
    users = []
    sessions = []
    # Walk through the folder structure
    for participant_folder in os.listdir(data_path):

      participant_path = os.path.join(data_path, participant_folder)
      if not os.path.isdir(participant_path):
        continue
      user = os.path.basename(participant_path)
      if ('p40' in user or 'p39' in user or 'p41' in user):
        continue
      for session_id in ['1', '2', '3']:
        file_pattern = os.path.join(participant_path, f'*-{session_id}.npy')
        real = np.array([])
        imag = np.array([])
        force = np.array([])
        for file in glob.glob(file_pattern):
          if 'real' in file:
            with open(file, 'rb') as f:
              real = np.load(f)
          elif 'imag' in file:
            with open(file, 'rb') as f:
              imag = np.load(f)
          elif 'force' in file:
            with open(file, 'rb') as f:
              force = np.load(f)
        num_entries = real.shape[0]
        new_data = np.concatenate([real, imag], axis=1)
        new_force = force
        if is_windowed:
          new_data, new_force = create_windowed_data(new_data, force, window_size=window_size)
        if data is not None:
          data = np.append(data, new_data, axis=0)
        else:
          data = new_data
        labels = np.append(labels, new_force, axis=0) if labels is not None else new_force
        users.extend([user] * new_data.shape[0])
        sessions.extend([session_id] * num_entries)
    return data, labels, np.array(users), np.array(sessions)

# Path to the extracted dataset
data_path = '/home/ubuntu/paper_arm_model/EIT_Model_Input_Resource/pinch-pressure/batch-2/#processed-data'

# Load and preprocess the data
data, labels, users, sessions = load_and_preprocess_data(data_path)

print(data.shape)
print(labels.shape)
# label_set = np.unique(labels)
print(np.unique(users))
print(np.unique(sessions))
# Out:
# (315274, 10, 12)
# (315274,)
# ['p24' 'p25' 'p26' 'p27' 'p28' 'p29' 'p30' 'p31' 'p32' 'p33' 'p34' 'p35'
#  'p36' 'p37' 'p38']
# ['1' '2' '3']

# %%
#@title Approach 1 - RandomForestRegressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import LeaveOneGroupOut

is_LOSO = True #@param{type: "boolean"}
num_estimators = 10 #@param
def pred(X_train, X_test, y_train, y_test):
  model = RandomForestRegressor(
      n_estimators=num_estimators,
      random_state=42)
  if len(X_train.shape) > 2:
    X_train = X_train.reshape(X_train.shape[0], window_size * 12)
    X_test = X_test.reshape(X_test.shape[0], window_size * 12)

  model.fit(X_train, y_train)

  y_pred = model.predict(X_test)
  mse = mean_squared_error(y_test, y_pred)
  r2 = r2_score(y_test, y_pred)
  return (mse, r2)


if not is_LOSO:
  X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)
  mse, r2 = pred(X_train, X_test, y_train, y_test)
  print(mse)
  print(r2)
else:
  logo = LeaveOneGroupOut()
  logo_session = LeaveOneGroupOut()
  LOSO_result = {}
  print(users)
  for train_index, test_index in logo.split(data, labels, groups=users):
    current_group = users[test_index[0]]
    print(users[test_index])
    X_train, X_test = data[train_index], data[test_index]
    y_train, y_test = labels[train_index], labels[test_index]
    LOSO_result[current_group] = pred(X_train, X_test, y_train, y_test)
    print(LOSO_result[current_group])
    for fs_train_index, fs_test_index in logo_session.split(X_test, y_test, groups=sessions[test_index]):
      current_session = sessions[fs_test_index[0]]
      print(sessions[fs_test_index])
      fs_X_train, fs_X_test = X_test[fs_train_index], X_test[fs_test_index]
      fs_y_train, fs_y_test = y_test[fs_train_index], y_test[fs_test_index]
      LOSO_result[current_group] = pred(fs_X_test, X_test, fs_y_test, y_test)
      print(LOSO_result[current_group])
      break


  print(LOSO_result)
# Out:
# ['p30' 'p30' 'p30' ... 'p35' 'p35' 'p35']
# ['p24' 'p24' 'p24' ... 'p24' 'p24' 'p24']
# (9.413270236156059, -0.21123565495472052)
# ['1' '1' '1' ... '3' '3' '3']
# (6.195065701768819, 0.20286103824491553)
# ['p25' 'p25' 'p25' ... 'p25' 'p25' 'p25']
# (11.835988116386982, -0.08484882802127336)
# ['1' '1' '1' ... '1' '1' '1']
# (6.292808752270733, 0.4232212695101262)
# ['p26' 'p26' 'p26' ... 'p26' 'p26' 'p26']
# (7.5939921820876375, -0.355172499432834)
# ['1' '1' '1' ... '2' '2' '2']
# (4.113032040691463, 0.26601611152845717)
# ['p27' 'p27' 'p27' ... 'p27' 'p27' 'p27']
# (15.983847812670401, -0.08672778400940029)
# ['1' '1' '1' ... '2' '2' '2']
# (8.65003166310415, 0.4118919392234982)
# ['p28' 'p28' 'p28' ... 'p28' 'p28' 'p28']
# (14.606040890413873, -0.0553088092038625)
# ['1' '1' '1' ... '1' '1' '1']
# (10.088758915184602, 0.271071727307301)
# ['p29' 'p29' 'p29' ... 'p29' 'p29' 'p29']
# (13.073590553933421, 0.018120174086018626)
# ['1' '1' '1' ... '1' '1' '1']
# (8.516902301211134, 0.3603459956665427)
# ['p30' 'p30' 'p30' ... 'p30' 'p30' 'p30']
# (14.72405742289176, -0.05723037711945822)
# ['1' '1' '1' ... '1' '1' '1']
# (9.923516182209832, 0.2874625210740138)
# ['p31' 'p31' 'p31' ... 'p31' 'p31' 'p31']
# (17.738088119400132, -0.11455541724486107)
# ['1' '1' '1' ... '1' '1' '1']
# (10.61755055667554, 0.33285659586552363)
# ['p32' 'p32' 'p32' ... 'p32' 'p32' 'p32']
# (14.784548170339146, -0.04422610393189186)
# ['1' '1' '1' ... '1' '1' '1']
# (9.71573504418458, 0.3137819272436593)
# ['p33' 'p33' 'p33' ... 'p33' 'p33' 'p33']

# %%
# LOSO_result = {'p24': (24.90697532838613, -2.1707521764685893), 'p25': (25.088540465810784, -1.3534596657668154), 'p26': (10.721591102270521, -0.9132737279275891), 'p27': (26.489628593655457, -0.8016027463905722), 'p28': (22.444215871204605, -0.6584552065639588), 'p29': (25.06006570312082, -0.9221363285487973), 'p30': (26.147049767423365, -0.880818944955466), 'p31': (42.90885222261295, -1.6780911775022016), 'p32': (59.18871376844276, -3.3029442037528387), 'p33': (18.589459724654944, -0.7277160071741955), 'p34': (15.91594533759355, -0.4680131948250663), 'p35': (21.059298312598553, -0.44994203569086144), 'p36': (12.978648195919392, -0.4947250065216089), 'p37': (5.060074266122278, -0.3490838856104239), 'p38': (9.640156720249117, -0.2979091084233212)}

print(LOSO_result)
print(LOSO_result.values())
print( np.mean([i for i, j in LOSO_result.values()]))
print( np.mean([j for i, j in LOSO_result.values()]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # LOSO_result = {'p24': (24.90697532838613, -2.1707521764685893), 'p25': (25.088540465810784, -1.3534596657668154), 'p26': (10.721591102270521, -0.9132737279275891), 'p27': (26.489628593655457, -0.8016027463905722), 'p28': (22.444215871204605, -0.6584552065639588), 'p29': (25.06006570312082, -0.9221363285487973), 'p30': (26.147049767423365, -0.880818944955466), 'p31': (42.90885222261295, -1.6780911775022016), 'p32': (59.18871376844276, -3.3029442037528387), 'p33': (18.589459724654944, -0.7277160071741955), 'p34': (15.91594533759355, -0.4680131948250663), 'p35': (21.059298312598553, -0.44994203569086144), 'p36': (12.978648195919392, -0.4947250065216089), 'p37': (5.060074266122278, -0.3490838856104239), 'p38': (9.640156720249117, -0.2979091084233212)}
# ----> 3 print(LOSO_result)
#       4 print(LOSO_result.values())
#       5 print( np.mean([i for i, j in LOSO_result.values()]))
#
# NameError: name 'LOSO_result' is not defined

# %%
#@title Approach 1 - RandomForestClassifier - 3 class

import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns


is_finegrained = False #@param{type: "boolean"}
is_LOSO = True #@param{type: "boolean"}

low_pressure_boundary = 4 #@param
high_pressure_boundary = 7 #@param
classifier = RandomForestClassifier(n_estimators=10, random_state=42)

target_names = [str(i) for i in range(10)] if is_finegrained else ['light', 'median', 'hard']

def classify_pressure(pressure):
  if is_finegrained:
    if pressure >= 9.5:
      return 9
    else:
      return int(np.round(pressure))
  else:
    if pressure == 0:
      return 0
    elif pressure < low_pressure_boundary:
      return 1
    elif pressure < high_pressure_boundary:
      return 2
    else:
      return 3

def pred(X_train, X_test, y_train, y_test):
  classifier.fit(X_train, y_train)
  y_pred = classifier.predict(X_test)
  accuracy = accuracy_score(y_test, y_pred)
  # class_report = classification_report(y_test, y_pred, target_names=target_names)
  print(f"Accuracy: {accuracy * 100}")
  # print(f"Classification Report:\n{class_report}")
  # Plot confusion matrix as a heatmap
  # conf_matrix = confusion_matrix(y_test, y_pred)
  # plt.figure(figsize=(10, 7))
  # sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
  # plt.xlabel('Predicted')
  # plt.ylabel('Actual')
  # plt.title('Confusion Matrix')
  # plt.show()
  return accuracy

labels_c = np.array([classify_pressure(y_i) for y_i in labels])
if not is_LOSO:
  X_train, X_test, y_train, y_test = train_test_split(data, labels_c, test_size=0.2, random_state=42)
  accuracy = pred(X_train, X_test, y_train, y_test)
  print(accuracy)
else:
  logo = LeaveOneGroupOut()
  logo_session = LeaveOneGroupOut()
  LOSO_result = {}
  for train_index, test_index in logo.split(data, labels_c, groups=users):
    current_group = users[test_index[0]]
    print(users[test_index])
    X_train, X_test = data[train_index], data[test_index]
    y_train, y_test = labels_c[train_index], labels_c[test_index]
    LOSO_result[current_group] = pred(X_train, X_test, y_train, y_test)

    for fs_train_index, fs_test_index in logo_session.split(X_test, y_test, groups=sessions[test_index]):
      current_session = sessions[fs_test_index[0]]
      print(sessions[fs_test_index])
      fs_X_train, fs_X_test = X_test[fs_train_index], X_test[fs_test_index]
      fs_y_train, fs_y_test = y_test[fs_train_index], y_test[fs_test_index]
      LOSO_result[current_group] = pred(fs_X_test, X_test, fs_y_test, y_test)
      break

  print(LOSO_result)
print(np.mean(list(LOSO_result.values())))
# Out:
# ['p24' 'p24' 'p24' ... 'p24' 'p24' 'p24']
# Accuracy: 31.58879273130923
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 57.24710670750509
# ['p25' 'p25' 'p25' ... 'p25' 'p25' 'p25']
# Accuracy: 43.89288047028086
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 51.324997667257634
# ['p26' 'p26' 'p26' ... 'p26' 'p26' 'p26']
# Accuracy: 40.183711753671005
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 57.88213985380685
# ['p27' 'p27' 'p27' ... 'p27' 'p27' 'p27']
# Accuracy: 12.127236580516898
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 88.5296914167171
# ['p28' 'p28' 'p28' ... 'p28' 'p28' 'p28']
# Accuracy: 53.80035721373289
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 66.31772177019249
# ['p29' 'p29' 'p29' ... 'p29' 'p29' 'p29']
# Accuracy: 53.39649911674964
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 88.43209678282747
# ['p30' 'p30' 'p30' ... 'p30' 'p30' 'p30']
# Accuracy: 43.58525821969547
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 52.93603148729774
# ['p31' 'p31' 'p31' ... 'p31' 'p31' 'p31']
# Accuracy: 28.381534039877852
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 61.882522004670385
# ['p32' 'p32' 'p32' ... 'p32' 'p32' 'p32']
# Accuracy: 61.207396430642355
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 78.23593840603054
# ['p33' 'p33' 'p33' ... 'p33' 'p33' 'p33']
# Accuracy: 18.52098367547117
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 77.90233307643804
# ['p34' 'p34' 'p34' ... 'p34' 'p34' 'p34']
# Accuracy: 61.860346259502975
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 62.013671500670796
# ['p35' 'p35' 'p35' ... 'p35' 'p35' 'p35']
# Accuracy: 42.50219431503612
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 64.79643508203363
# ['p36' 'p36' 'p36' ... 'p36' 'p36' 'p36']
# Accuracy: 64.26958775817376
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 73.60983359812694
# ['p37' 'p37' 'p37' ... 'p37' 'p37' 'p37']
# Accuracy: 61.92629815745394
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 78.76046901172529
# ['p38' 'p38' 'p38' ... 'p38' 'p38' 'p38']
# Accuracy: 31.190035347584583
# ['1' '1' '1' ... '1' '1' '1']
# Accuracy: 93.24608651742132
# {'p24': 0.5724710670750509, 'p25': 0.5132499766725763, 'p26': 0.5788213985380685, 'p27': 0.8852969141671709, 'p28': 0.663177217701925, 'p29': 0.8843209678282747, 'p30': 0.5293603148729774, 'p31': 0.6188252200467038, 'p32': 0.7823593840603054, 'p33': 0.7790233307643804, 'p34': 0.620136715006708, 'p35': 0.6479643508203362, 'p36': 0.7360983359812694, 'p37': 0.787604690117253, 'p38': 0.9324608651742131}
# 0.7020780499218141

# %%
print(LOSO_result.values())
print(np.mean(list(LOSO_result.values())))
# Out:
# dict_values([(3.353999376296997, 0.5076717138290405), (1.2844772338867188, 0.7334468960762024), (2.530693531036377, 0.6102748513221741), (1.1492737531661987, 0.7537103295326233), (2.2010581493377686, 0.6589004993438721), (1.7393109798431396, 0.6807383298873901), (2.7376911640167236, 0.6069437265396118), (1.4029844999313354, 0.6809940338134766), (1.4247864484786987, 0.7117848992347717), (2.3078644275665283, 0.6181976199150085), (1.4506057500839233, 0.7286573648452759), (1.832534909248352, 0.6841179728507996), (1.3098976612091064, 0.743127703666687), (1.4241036176681519, 0.76372230052948), (1.1943401098251343, 0.6863076686859131)])
# 1.2504072507222495

# %%
# Evaluate the classifier
accuracy = accuracy_score(y_test_classification, y_pred)
conf_matrix = confusion_matrix(y_test_classification, y_pred)
class_report = classification_report(y_test_classification, y_pred, target_names=target_names)

# Print accuracy and classification report
print(f"Accuracy: {accuracy * 100}")
print(f"Classification Report:\n{class_report}")

# Plot confusion matrix as a heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=["light", "median", "hard"])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
#@title Modeling

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Reshape
from tensorflow.keras.callbacks import ModelCheckpoint


model = Sequential()
# model.add(Reshape((12, 1)))
# model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=(12,)))
# model.add(MaxPooling1D(pool_size=2))
# model.add(Conv1D(64, kernel_size=3, activation='relu'))
# model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))


# Define the path to save the best model
checkpoint_filepath = '/tmp/best_model.h5'

# Create a ModelCheckpoint callback to save the model with the lowest validation loss
checkpoint = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',  # You can also use 'val_accuracy' to monitor accuracy instead
    verbose=1,
    save_best_only=True,
    mode='min'  # 'min' for minimizing loss, 'max' for maximizing accuracy
)

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test), callbacks=[checkpoint])

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
test_acc
# Out:
# Epoch 1/20
# 8164/8176 [============================>.] - ETA: 0s - loss: 14.7458 - accuracy: 3.4067e-04
# Epoch 1: val_loss improved from inf to 14.71763, saving model to /tmp/best_model.h5
# 8176/8176 [==============================] - 17s 2ms/step - loss: 14.7469 - accuracy: 3.4019e-04 - val_loss: 14.7176 - val_accuracy: 3.6694e-04
# Epoch 2/20
# 8154/8176 [============================>.] - ETA: 0s - loss: 14.7416 - accuracy: 3.4109e-04
# Epoch 2: val_loss did not improve from 14.71763
# 8176/8176 [==============================] - 17s 2ms/step - loss: 14.7448 - accuracy: 3.4019e-04 - val_loss: 14.7176 - val_accuracy: 3.6694e-04
# Epoch 3/20
# 8169/8176 [============================>.] - ETA: 0s - loss: 14.7449 - accuracy: 3.4046e-04
# Epoch 3: val_loss did not improve from 14.71763
# 8176/8176 [==============================] - 17s 2ms/step - loss: 14.7448 - accuracy: 3.4019e-04 - val_loss: 14.7176 - val_accuracy: 3.6694e-04
# Epoch 4/20
# 1791/8176 [=====>........................] - ETA: 11s - loss: 14.8370 - accuracy: 3.8386e-04
# /export/hda3/borglet/remote_hdd_fs_dirs/0.colab_kernel_deepmind_gpu_py3_cadyxu.kernel.cadyxu.3741417284830.14b334fb3717c109/mount/server/dm_notebook3.par/google3/third_party/py/tf_keras/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-93391633eccc> in <module>()
#      35
#      36 # Train the model
# ---> 37 history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test), callbacks=[checkpoint])
#      38
#      39 # Evaluate the model
#
# /export/hda3/borglet/remote_hdd_fs_dirs/0.colab_kernel_deepmind_gpu_py3_cadyxu.kernel.cadyxu.3741417284830.14b334fb3717c109/mount/server/dm_notebook3.par/google3/third_party/py/tf_keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /export/hda3/borglet/remote_hdd_fs_dirs/0.colab_kernel_deepmind_gpu_py3_cadyxu.kernel.cadyxu.3741417284830.14b334fb3717c109/mount/server/dm_notebook3.par/google3/third_party/py/tf_keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1802                         ):
#    1803                             callbacks.on_train_batch_begin(step)
# -> 1804                             tmp_logs = self.train_function(iterator)
#    1805                             if data_handler.should_sync:
#    1806                                 context.async_wait()
#
# /export/hda3/borglet/remote_hdd_fs_dirs/0.colab_kernel_deepmind_gpu_py3_cadyxu.kernel.cadyxu.3741417284830.14b334fb3717c109/mount/server/dm_notebook3.par/google3/third_party/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /export/hda3/borglet/remote_hdd_fs_dirs/0.colab_kernel_deepmind_gpu_py3_cadyxu.kernel.cadyxu.3741417284830.14b334fb3717c109/mount/server/dm_notebook3.par/google3/third_party/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /export/hda3/borglet/remote_hdd_fs_dirs/0.colab_kernel_deepmind_gpu_py3_cadyxu.kernel.cadyxu.3741417284830.14b334fb3717c109/mount/server/dm_notebook3.par/google3/third_party/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     867       # In this case we have created variables on the first call, so we run the
#     868       # defunned version which is guaranteed to never create variables.
# --> 869       return tracing_compilation.call_function(
#     870           args, kwds, self._no_variable_creation_config
#     871       )
#
# /export/hda3/borglet/remote_hdd_fs_dirs/0.colab_kernel_deepmind_gpu_py3_cadyxu.kernel.cadyxu.3741417284830.14b334fb3717c109/mount/server/dm_notebook3.par/google3/third_party/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /export/hda3/borglet/remote_hdd_fs_dirs/0.colab_kernel_deepmind_gpu_py3_cadyxu.kernel.cadyxu.3741417284830.14b334fb3717c109/mount/server/dm_notebook3.par/google3/third_party/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /export/hda3/borglet/remote_hdd_fs_dirs/0.colab_kernel_deepmind_gpu_py3_cadyxu.kernel.cadyxu.3741417284830.14b334fb3717c109/mount/server/dm_notebook3.par/google3/third_party/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /export/hda3/borglet/remote_hdd_fs_dirs/0.colab_kernel_deepmind_gpu_py3_cadyxu.kernel.cadyxu.3741417284830.14b334fb3717c109/mount/server/dm_notebook3.par/google3/third_party/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /export/hda3/borglet/remote_hdd_fs_dirs/0.colab_kernel_deepmind_gpu_py3_cadyxu.kernel.cadyxu.3741417284830.14b334fb3717c109/mount/server/dm_notebook3.par/google3/third_party/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1665     cancellation_context = cancellation.context()
#    1666     if cancellation_context is None:
# -> 1667       outputs = execute.execute(
#    1668           name.decode("utf-8"),
#    1669           num_outputs=num_outputs,
#
# /export/hda3/borglet/remote_hdd_fs_dirs/0.colab_kernel_deepmind_gpu_py3_cadyxu.kernel.cadyxu.3741417284830.14b334fb3717c109/mount/server/dm_notebook3.par/google3/third_party/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
best_model = tf.keras.models.load_model('/tmp/best_model.h5')

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Sample training and evaluation dataset setup
# This assumes you have your X_train, X_test, y_train, and y_test data ready

# Convert y_test from one-hot encoding to single class labels (for confusion matrix)
y_test_labels = np.argmax(y_test, axis=1)

# Make predictions using the trained model
y_pred = best_model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)

# Compute the confusion matrix
conf_matrix = confusion_matrix(y_test_labels, y_pred_labels)

# Plot the confusion matrix using seaborn's heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=label_to_index.keys(), yticklabels=label_to_index.keys())
plt.title("Confusion Matrix")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.show()
# Out:
# 223/223 [==============================] - 0s 1ms/step

# %%
import matplotlib.pyplot as plt

# Assuming `history` is the variable that stores the training history from model.fit()

# Create subplots for loss and accuracy curves
fig, axs = plt.subplots(2, 1, figsize=(15, 12))

# Plot the training and validation loss
axs[0].plot(history.history['loss'], label='Training Loss')
axs[0].plot(history.history['val_loss'], label='Validation Loss')
axs[0].set_title('Loss Curve')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')
axs[0].legend(loc='upper right')

# Plot the training and validation accuracy
axs[1].plot(history.history['accuracy'], label='Training Accuracy')
axs[1].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[1].set_title('Accuracy Curve')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
axs[1].legend(loc='lower right')

# Display the plots
plt.show()

# %%
# with gfile.Open('/x20/users/ca/cadyxu/eit/microgesture/best_model.h5', 'wb') as f:
#   best_model.save(f)
gfile.Copy('/tmp/best_model.h5', '/x20/users/ca/cadyxu/eit/microgesture/best_model.h5', overwrite=True)

# %%
import numpy as np
from sklearn.model_selection import LeaveOneGroupOut
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical

# Assume data, labels, and users (user IDs) are available from earlier preprocessing
# data: The input data (X)
# labels: The target labels (y)
# users: User or participant IDs corresponding to each data point

# Convert labels to one-hot encoding
labels_one_hot = to_categorical(indexed_labels, num_classes=len(label_set))

# Initialize LOSO cross-validator
logo = LeaveOneGroupOut()

# Prepare to store accuracy from each fold
fold_accuracies = []

LOSO_result = {}

# Loop over each fold in LOSO
for train_index, test_index in logo.split(normalized_data, labels_one_hot, groups=sessions):
    # Split data into training and testing sets for the current fold
    X_train, X_test = data[train_index], data[test_index]
    y_train, y_test = labels_one_hot[train_index], labels_one_hot[test_index]

    model = Sequential()
    model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=(60,
    12)))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(64, kernel_size=3, activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())

    model.add(Dense(64, activation='relu'))
    model.add(Dense(len(label_set), activation='softmax'))

    # Compile the model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])



    # Define the path to save the best model
    checkpoint_filepath = f'/tmp/{users[test_index][0]}_best_model.h5'

    # Create a ModelCheckpoint callback to save the model with the lowest validation loss
    checkpoint = ModelCheckpoint(
        filepath=checkpoint_filepath,
        monitor='val_accuracy',  # You can also use 'val_accuracy' to monitor accuracy instead
        verbose=1,
        save_best_only=True,
        mode='max'  # 'min' for minimizing loss, 'max' for maximizing accuracy
    )

    # Compile the model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test), callbacks=[checkpoint])

    # Evaluate the model
    cur_best_model = tf.keras.models.load_model(checkpoint_filepath)
    test_loss, test_acc = cur_best_model.evaluate(X_test, y_test)
    gfile.Copy(checkpoint_filepath, f'/x20/users/ca/cadyxu/eit/microgesture/{users[test_index][0]}_best_model.h5', overwrite=True)

    # Save the test accuracy for this fold
    fold_accuracies.append(test_acc)
    print(f"LOSO user: {users[test_index]}")
    print(f"Fold Accuracy: {test_acc} loss: {test_loss}")
    LOSO_result[users[test_index][0]] = (test_acc, test_loss)

# Calculate the average accuracy across all folds
avg_accuracy = np.mean(fold_accuracies)
print(f"Average LOSO Accuracy: {avg_accuracy}")
# Out:
# Epoch 1/30
# 735/735 [==============================] - ETA: 0s - loss: 1.7697 - accuracy: 0.3004
# Epoch 1: val_accuracy improved from -inf to 0.26259, saving model to /tmp/p01_best_model.h5
# 735/735 [==============================] - 6s 4ms/step - loss: 1.7697 - accuracy: 0.3004 - val_loss: 3.6996 - val_accuracy: 0.2626
# Epoch 2/30
# 719/735 [============================>.] - ETA: 0s - loss: 1.3270 - accuracy: 0.4822
# Epoch 2: val_accuracy improved from 0.26259 to 0.27391, saving model to /tmp/p01_best_model.h5
# 735/735 [==============================] - 3s 4ms/step - loss: 1.3245 - accuracy: 0.4837 - val_loss: 3.1971 - val_accuracy: 0.2739
# Epoch 3/30
# 727/735 [============================>.] - ETA: 0s - loss: 1.0405 - accuracy: 0.5942
# Epoch 3: val_accuracy improved from 0.27391 to 0.27957, saving model to /tmp/p01_best_model.h5
# 735/735 [==============================] - 3s 4ms/step - loss: 1.0395 - accuracy: 0.5944 - val_loss: 4.5717 - val_accuracy: 0.2796
# Epoch 4/30
# 725/735 [============================>.] - ETA: 0s - loss: 0.8924 - accuracy: 0.6529
# Epoch 4: val_accuracy improved from 0.27957 to 0.32650, saving model to /tmp/p01_best_model.h5
# 735/735 [==============================] - 3s 4ms/step - loss: 0.8935 - accuracy: 0.6526 - val_loss: 3.1166 - val_accuracy: 0.3265
# Epoch 5/30
# 734/735 [============================>.] - ETA: 0s - loss: 0.8003 - accuracy: 0.6952
# Epoch 5: val_accuracy did not improve from 0.32650
# 735/735 [==============================] - 3s 4ms/step - loss: 0.8004 - accuracy: 0.6951 - val_loss: 5.5639 - val_accuracy: 0.3033
# Epoch 6/30
# 728/735 [============================>.] - ETA: 0s - loss: 0.7431 - accuracy: 0.7163
# Epoch 6: val_accuracy improved from 0.32650 to 0.32806, saving model to /tmp/p01_best_model.h5
# 735/735 [==============================] - 3s 4ms/step - loss: 0.7428 - accuracy: 0.7169 - val_loss: 3.8447 - val_accuracy: 0.3281
# Epoch 7/30
# 722/735 [============================>.] - ETA: 0s - loss: 0.7294 - accuracy: 0.7216
# Epoch 7: val_accuracy improved from 0.32806 to 0.43897, saving model to /tmp/p01_best_model.h5
# 735/735 [==============================] - 3s 4ms/step - loss: 0.7294 - accuracy: 0.7217 - val_loss: 3.2561 - val_accuracy: 0.4390
# Epoch 8/30
# 735/735 [==============================] - ETA: 0s - loss: 0.6818 - accuracy: 0.7437
# Epoch 8: val_accuracy improved from 0.43897 to 0.44545, saving model to /tmp/p01_best_model.h5
# 735/735 [==============================] - 3s 4ms/step - loss: 0.6818 - accuracy: 0.7437 - val_loss: 4.0125 - val_accuracy: 0.4454
# Epoch 9/30
# 734/735 [============================>.] - ETA: 0s - loss: 0.6439 - accuracy: 0.7576
# Epoch 9: val_accuracy did not improve from 0.44545
# 735/735 [==============================] - 3s 4ms/step - loss: 0.6444 - accuracy: 0.7575 - val_loss: 4.2845 - val_accuracy: 0.3833
# Epoch 10/30
# 720/735 [============================>.] - ETA: 0s - loss: 0.6232 - accuracy: 0.7670
# Epoch 10: val_accuracy improved from 0.44545 to 0.49139, saving model to /tmp/p01_best_model.h5
# 735/735 [==============================] - 3s 4ms/step - loss: 0.6222 - accuracy: 0.7674 - val_loss: 3.1769 - val_accuracy: 0.4914
# Epoch 11/30
# 722/735 [============================>.] - ETA: 0s - loss: 0.5887 - accuracy: 0.7771
# Epoch 11: val_accuracy did not improve from 0.49139
# 735/735 [==============================] - 3s 4ms/step - loss: 0.5875 - accuracy: 0.7775 - val_loss: 3.7448 - val_accuracy: 0.4710
# Epoch 12/30
# 725/735 [============================>.] - ETA: 0s - loss: 0.5528 - accuracy: 0.7935
# Epoch 12: val_accuracy did not improve from 0.49139
# 735/735 [==============================] - 3s 4ms/step - loss: 0.5528 - accuracy: 0.7935 - val_loss: 4.6801 - val_accuracy: 0.4285
# Epoch 13/30
# 731/735 [============================>.] - ETA: 0s - loss: 0.5688 - accuracy: 0.7893
# Epoch 13: val_accuracy did not improve from 0.49139
# 735/735 [==============================] - 3s 4ms/step - loss: 0.5690 - accuracy: 0.7893 - val_loss: 4.0499 - val_accuracy: 0.4564
# Epoch 14/30
# 723/735 [============================>.] - ETA: 0s - loss: 0.5371 - accuracy: 0.8013
# Epoch 14: val_accuracy did not improve from 0.49139
# 735/735 [==============================] - 3s 4ms/step - loss: 0.5371 - accuracy: 0.8010 - val_loss: 5.3895 - val_accuracy: 0.3981
# Epoch 15/30
# 720/735 [============================>.] - ETA: 0s - loss: 0.5326 - accuracy: 0.8061
# Epoch 15: val_accuracy did not improve from 0.49139
# 735/735 [==============================] - 3s 4ms/step - loss: 0.5313 - accuracy: 0.8063 - val_loss: 4.2608 - val_accuracy: 0.4534
# Epoch 16/30
# 726/735 [============================>.] - ETA: 0s - loss: 0.4824 - accuracy: 0.8220
# Epoch 16: val_accuracy did not improve from 0.49139
# 735/735 [==============================] - 3s 4ms/step - loss: 0.4831 - accuracy: 0.8218 - val_loss: 5.0669 - val_accuracy: 0.3922
# Epoch 17/30
# 731/735 [============================>.] - ETA: 0s - loss: 0.5262 - accuracy: 0.8042
# Epoch 17: val_accuracy did not improve from 0.49139
# 735/735 [==============================] - 3s 4ms/step - loss: 0.5258 - accuracy: 0.8044 - val_loss: 5.8609 - val_accuracy: 0.3877
# Epoch 18/30
# 722/735 [============================>.] - ETA: 0s - loss: 0.4603 - accuracy: 0.8305
# Epoch 18: val_accuracy did not improve from 0.49139
# 735/735 [==============================] - 3s 4ms/step - loss: 0.4609 - accuracy: 0.8310 - val_loss: 6.5464 - val_accuracy: 0.3523
# Epoch 19/30
# 720/735 [============================>.] - ETA: 0s - loss: 0.4650 - accuracy: 0.8280
# Epoch 19: val_accuracy did not improve from 0.49139
# 735/735 [==============================] - 3s 4ms/step - loss: 0.4639 - accuracy: 0.8283 - val_loss: 4.7021 - val_accuracy: 0.4525
# Epoch 20/30
# 721/735 [============================>.] - ETA: 0s - loss: 0.4495 - accuracy: 0.8336
# Epoch 20: val_accuracy did not improve from 0.49139
# 735/735 [==============================] - 3s 4ms/step - loss: 0.4483 - accuracy: 0.8340 - val_loss: 4.7983 - val_accuracy: 0.4746
# Epoch 21/30
# 734/735 [============================>.] - ETA: 0s - loss: 0.4405 - accuracy: 0.8395
# Epoch 21: val_accuracy did not improve from 0.49139
# 735/735 [==============================] - 3s 4ms/step - loss: 0.4410 - accuracy: 0.8394 - val_loss: 7.2796 - val_accuracy: 0.2864
# Epoch 22/30
# 734/735 [============================>.] - ETA: 0s - loss: 0.4598 - accuracy: 0.8292
# Epoch 22: val_accuracy did not improve from 0.49139
# 735/735 [==============================] - 3s 4ms/step - loss: 0.4606 - accuracy: 0.8292 - val_loss: 6.2352 - val_accuracy: 0.4297
# Epoch 23/30
# 727/735 [============================>.] - ETA: 0s - loss: 0.4240 - accuracy: 0.8469
# Epoch 23: val_accuracy improved from 0.49139 to 0.51756, saving model to /tmp/p01_best_model.h5
# 735/735 [==============================] - 3s 4ms/step - loss: 0.4232 - accuracy: 0.8472 - val_loss: 4.4109 - val_accuracy: 0.5176
# Epoch 24/30
# 719/735 [============================>.] - ETA: 0s - loss: 0.4064 - accuracy: 0.8489
# Epoch 24: val_accuracy did not improve from 0.51756
# 735/735 [==============================] - 3s 4ms/step - loss: 0.4055 - accuracy: 0.8495 - val_loss: 5.6344 - val_accuracy: 0.4234
# Epoch 25/30
# 720/735 [============================>.] - ETA: 0s - loss: 0.4307 - accuracy: 0.8449
# Epoch 25: val_accuracy did not improve from 0.51756
# 735/735 [==============================] - 3s 4ms/step - loss: 0.4299 - accuracy: 0.8453 - val_loss: 5.4760 - val_accuracy: 0.4473
# Epoch 26/30
# 727/735 [============================>.] - ETA: 0s - loss: 0.4317 - accuracy: 0.8464
# Epoch 26: val_accuracy did not improve from 0.51756
# 735/735 [==============================] - 3s 4ms/step - loss: 0.4309 - accuracy: 0.8464 - val_loss: 5.4322 - val_accuracy: 0.4608
# Epoch 27/30
# 733/735 [============================>.] - ETA: 0s - loss: 0.4054 - accuracy: 0.8526
# Epoch 27: val_accuracy did not improve from 0.51756
# 735/735 [==============================] - 3s 4ms/step - loss: 0.4069 - accuracy: 0.8525 - val_loss: 6.0416 - val_accuracy: 0.3683
# Epoch 28/30
# 724/735 [============================>.] - ETA: 0s - loss: 0.4416 - accuracy: 0.8388
# Epoch 28: val_accuracy did not improve from 0.51756
# 735/735 [==============================] - 3s 4ms/step - loss: 0.4405 - accuracy: 0.8394 - val_loss: 5.1356 - val_accuracy: 0.4792
# Epoch 29/30
# 721/735 [============================>.] - ETA: 0s - loss: 0.3903 - accuracy: 0.8585
# Epoch 29: val_accuracy did not improve from 0.51756
# 735/735 [==============================] - 3s 4ms/step - loss: 0.3924 - accuracy: 0.8581 - val_loss: 4.9659 - val_accuracy: 0.4675
# Epoch 30/30
# 728/735 [============================>.] - ETA: 0s - loss: 0.3843 - accuracy: 0.8621
# Epoch 30: val_accuracy did not improve from 0.51756
# 735/735 [==============================] - 3s 4ms/step - loss: 0.3842 - accuracy: 0.8622 - val_loss: 5.7621 - val_accuracy: 0.4734
# 381/381 [==============================] - 1s 2ms/step - loss: 4.4109 - accuracy: 0.5176
# LOSO user: ['p01' 'p01' 'p01' ... 'p15' 'p15' 'p15']
# Fold Accuracy: 0.5175553560256958 loss: 4.410904407501221
# Epoch 1/30
# 750/761 [============================>.] - ETA: 0s - loss: 1.7936 - accuracy: 0.2919
# Epoch 1: val_accuracy improved from -inf to 0.19878, saving model to /tmp/p01_best_model.h5
# 761/761 [==============================] - 5s 4ms/step - loss: 1.7917 - accuracy: 0.2925 - val_loss: 2.6652 - val_accuracy: 0.1988
# Epoch 2/30
# 750/761 [============================>.] - ETA: 0s - loss: 1.3148 - accuracy: 0.4873
# Epoch 2: val_accuracy improved from 0.19878 to 0.25899, saving model to /tmp/p01_best_model.h5
# 761/761 [==============================] - 3s 4ms/step - loss: 1.3138 - accuracy: 0.4878 - val_loss: 3.1315 - val_accuracy: 0.2590
# Epoch 3/30
# 751/761 [============================>.] - ETA: 0s - loss: 1.0504 - accuracy: 0.5929
# Epoch 3: val_accuracy improved from 0.25899 to 0.26023, saving model to /tmp/p01_best_model.h5
# 761/761 [==============================] - 3s 4ms/step - loss: 1.0479 - accuracy: 0.5942 - val_loss: 2.9788 - val_accuracy: 0.2602
# Epoch 4/30
# 756/761 [============================>.] - ETA: 0s - loss: 0.9137 - accuracy: 0.6512
# Epoch 4: val_accuracy improved from 0.26023 to 0.35649, saving model to /tmp/p01_best_model.h5
# 761/761 [==============================] - 3s 4ms/step - loss: 0.9137 - accuracy: 0.6513 - val_loss: 2.5054 - val_accuracy: 0.3565
# Epoch 5/30
# 750/761 [============================>.] - ETA: 0s - loss: 0.8046 - accuracy: 0.6901
# Epoch 5: val_accuracy improved from 0.35649 to 0.44605, saving model to /tmp/p01_best_model.h5
# 761/761 [==============================] - 3s 4ms/step - loss: 0.8040 - accuracy: 0.6905 - val_loss: 2.4802 - val_accuracy: 0.4461
# Epoch 6/30
# 745/761 [============================>.] - ETA: 0s - loss: 0.7346 - accuracy: 0.7193
# Epoch 6: val_accuracy did not improve from 0.44605
# 761/761 [==============================] - 3s 4ms/step - loss: 0.7326 - accuracy: 0.7200 - val_loss: 3.7472 - val_accuracy: 0.3334
# Epoch 7/30
# 754/761 [============================>.] - ETA: 0s - loss: 0.6749 - accuracy: 0.7468
# Epoch 7: val_accuracy did not improve from 0.44605
# 761/761 [==============================] - 3s 4ms/step - loss: 0.6748 - accuracy: 0.7468 - val_loss: 5.4195 - val_accuracy: 0.1634
# Epoch 8/30
# 747/761 [============================>.] - ETA: 0s - loss: 0.6410 - accuracy: 0.7580
# Epoch 8: val_accuracy did not improve from 0.44605
# 761/761 [==============================] - 3s 3ms/step - loss: 0.6417 - accuracy: 0.7581 - val_loss: 4.1140 - val_accuracy: 0.2766
# Epoch 9/30
# 748/761 [============================>.] - ETA: 0s - loss: 0.6027 - accuracy: 0.7739
# Epoch 9: val_accuracy did not improve from 0.44605
# 761/761 [==============================] - 3s 4ms/step - loss: 0.6034 - accuracy: 0.7740 - val_loss: 4.2203 - val_accuracy: 0.2898
# Epoch 10/30
# 751/761 [============================>.] - ETA: 0s - loss: 0.5778 - accuracy: 0.7859
# Epoch 10: val_accuracy did not improve from 0.44605
# 761/761 [==============================] - 3s 4ms/step - loss: 0.5787 - accuracy: 0.7854 - val_loss: 3.9715 - val_accuracy: 0.3801
# Epoch 11/30
# 746/761 [============================>.] - ETA: 0s - loss: 0.5394 - accuracy: 0.7976
# Epoch 11: val_accuracy did not improve from 0.44605
# 761/761 [==============================] - 3s 4ms/step - loss: 0.5385 - accuracy: 0.7978 - val_loss: 3.5236 - val_accuracy: 0.4365
# Epoch 12/30
# 751/761 [============================>.] - ETA: 0s - loss: 0.5376 - accuracy: 0.8027
# Epoch 12: val_accuracy did not improve from 0.44605
# 761/761 [==============================] - 3s 4ms/step - loss: 0.5375 - accuracy: 0.8024 - val_loss: 4.5920 - val_accuracy: 0.3759
# Epoch 13/30
# 750/761 [============================>.] - ETA: 0s - loss: 0.5274 - accuracy: 0.8066
# Epoch 13: val_accuracy did not improve from 0.44605
# 761/761 [==============================] - 3s 4ms/step - loss: 0.5278 - accuracy: 0.8063 - val_loss: 4.2574 - val_accuracy: 0.3977
# Epoch 14/30
# 757/761 [============================>.] - ETA: 0s - loss: 0.4841 - accuracy: 0.8209
# Epoch 14: val_accuracy improved from 0.44605 to 0.47161, saving model to /tmp/p01_best_model.h5
# 761/761 [==============================] - 3s 4ms/step - loss: 0.4842 - accuracy: 0.8208 - val_loss: 3.2602 - val_accuracy: 0.4716
# Epoch 15/30
# 749/761 [============================>.] - ETA: 0s - loss: 0.4836 - accuracy: 0.8180
# Epoch 15: val_accuracy did not improve from 0.47161
# 761/761 [==============================] - 3s 3ms/step - loss: 0.4843 - accuracy: 0.8180 - val_loss: 3.6507 - val_accuracy: 0.3813
# Epoch 16/30
# 743/761 [============================>.] - ETA: 0s - loss: 0.4746 - accuracy: 0.8237
# Epoch 16: val_accuracy did not improve from 0.47161
# 761/761 [==============================] - 3s 3ms/step - loss: 0.4748 - accuracy: 0.8238 - val_loss: 5.4912 - val_accuracy: 0.3259
# Epoch 17/30
# 747/761 [============================>.] - ETA: 0s - loss: 0.4493 - accuracy: 0.8333
# Epoch 17: val_accuracy did not improve from 0.47161
# 761/761 [==============================] - 3s 3ms/step - loss: 0.4490 - accuracy: 0.8335 - val_loss: 3.7781 - val_accuracy: 0.4136
# Epoch 18/30
# 756/761 [============================>.] - ETA: 0s - loss: 0.4359 - accuracy: 0.8361
# Epoch 18: val_accuracy did not improve from 0.47161
# 761/761 [==============================] - 3s 3ms/step - loss: 0.4361 - accuracy: 0.8363 - val_loss: 4.5400 - val_accuracy: 0.3381
# Epoch 19/30
# 753/761 [============================>.] - ETA: 0s - loss: 0.4363 - accuracy: 0.8404
# Epoch 19: val_accuracy did not improve from 0.47161
# 761/761 [==============================] - 3s 3ms/step - loss: 0.4374 - accuracy: 0.8404 - val_loss: 3.9790 - val_accuracy: 0.3676
# Epoch 20/30
# 758/761 [============================>.] - ETA: 0s - loss: 0.4241 - accuracy: 0.8463
# Epoch 20: val_accuracy did not improve from 0.47161
# 761/761 [==============================] - 3s 3ms/step - loss: 0.4236 - accuracy: 0.8465 - val_loss: 5.0306 - val_accuracy: 0.3669
# Epoch 21/30
# 761/761 [==============================] - ETA: 0s - loss: 0.4120 - accuracy: 0.8499
# Epoch 21: val_accuracy improved from 0.47161 to 0.48307, saving model to /tmp/p01_best_model.h5
# 761/761 [==============================] - 3s 3ms/step - loss: 0.4120 - accuracy: 0.8499 - val_loss: 4.0056 - val_accuracy: 0.4831
# Epoch 22/30
# 753/761 [============================>.] - ETA: 0s - loss: 0.4197 - accuracy: 0.8455
# Epoch 22: val_accuracy did not improve from 0.48307
# 761/761 [==============================] - 3s 3ms/step - loss: 0.4193 - accuracy: 0.8454 - val_loss: 3.2934 - val_accuracy: 0.4440
# Epoch 23/30
# 756/761 [============================>.] - ETA: 0s - loss: 0.3950 - accuracy: 0.8571
# Epoch 23: val_accuracy did not improve from 0.48307
# 761/761 [==============================] - 3s 3ms/step - loss: 0.3947 - accuracy: 0.8571 - val_loss: 4.2409 - val_accuracy: 0.3650
# Epoch 24/30
# 756/761 [============================>.] - ETA: 0s - loss: 0.3960 - accuracy: 0.8586
# Epoch 24: val_accuracy did not improve from 0.48307
# 761/761 [==============================] - 3s 3ms/step - loss: 0.3955 - accuracy: 0.8587 - val_loss: 4.2575 - val_accuracy: 0.3477
# Epoch 25/30
# 744/761 [============================>.] - ETA: 0s - loss: 0.3751 - accuracy: 0.8623
# Epoch 25: val_accuracy did not improve from 0.48307
# 761/761 [==============================] - 3s 3ms/step - loss: 0.3749 - accuracy: 0.8623 - val_loss: 5.1221 - val_accuracy: 0.3604
# Epoch 26/30
# 761/761 [==============================] - ETA: 0s - loss: 0.3736 - accuracy: 0.8665
# Epoch 26: val_accuracy improved from 0.48307 to 0.50361, saving model to /tmp/p01_best_model.h5
# 761/761 [==============================] - 3s 3ms/step - loss: 0.3736 - accuracy: 0.8665 - val_loss: 3.2919 - val_accuracy: 0.5036
# Epoch 27/30
# 753/761 [============================>.] - ETA: 0s - loss: 0.3665 - accuracy: 0.8682
# Epoch 27: val_accuracy did not improve from 0.50361
# 761/761 [==============================] - 3s 3ms/step - loss: 0.3658 - accuracy: 0.8683 - val_loss: 3.8588 - val_accuracy: 0.4011
# Epoch 28/30
# 753/761 [============================>.] - ETA: 0s - loss: 0.3734 - accuracy: 0.8655
# Epoch 28: val_accuracy did not improve from 0.50361
# 761/761 [==============================] - 3s 3ms/step - loss: 0.3728 - accuracy: 0.8657 - val_loss: 3.6144 - val_accuracy: 0.4479
# Epoch 29/30
# 756/761 [============================>.] - ETA: 0s - loss: 0.3726 - accuracy: 0.8665
# Epoch 29: val_accuracy did not improve from 0.50361
# 761/761 [==============================] - 3s 3ms/step - loss: 0.3723 - accuracy: 0.8667 - val_loss: 4.5975 - val_accuracy: 0.3999
# Epoch 30/30
# 746/761 [============================>.] - ETA: 0s - loss: 0.3564 - accuracy: 0.8707
# Epoch 30: val_accuracy did not improve from 0.50361
# 761/761 [==============================] - 3s 3ms/step - loss: 0.3575 - accuracy: 0.8708 - val_loss: 4.0493 - val_accuracy: 0.4206
# 355/355 [==============================] - 1s 1ms/step - loss: 3.2919 - accuracy: 0.5036
# LOSO user: ['p01' 'p01' 'p01' ... 'p15' 'p15' 'p15']
# Fold Accuracy: 0.5036142468452454 loss: 3.291877269744873
# Epoch 1/30
# 756/756 [==============================] - ETA: 0s - loss: 1.7056 - accuracy: 0.3337
# Epoch 1: val_accuracy improved from -inf to 0.18549, saving model to /tmp/p01_best_model.h5
# 756/756 [==============================] - 4s 4ms/step - loss: 1.7056 - accuracy: 0.3337 - val_loss: 3.9922 - val_accuracy: 0.1855
# Epoch 2/30
# 753/756 [============================>.] - ETA: 0s - loss: 1.2064 - accuracy: 0.5327
# Epoch 2: val_accuracy improved from 0.18549 to 0.25489, saving model to /tmp/p01_best_model.h5
# 756/756 [==============================] - 3s 3ms/step - loss: 1.2060 - accuracy: 0.5330 - val_loss: 4.8649 - val_accuracy: 0.2549
# Epoch 3/30
# 744/756 [============================>.] - ETA: 0s - loss: 0.9564 - accuracy: 0.6325
# Epoch 3: val_accuracy improved from 0.25489 to 0.25802, saving model to /tmp/p01_best_model.h5
# 756/756 [==============================] - 3s 3ms/step - loss: 0.9558 - accuracy: 0.6326 - val_loss: 6.1768 - val_accuracy: 0.2580
# Epoch 4/30
# 753/756 [============================>.] - ETA: 0s - loss: 0.8035 - accuracy: 0.6941
# Epoch 4: val_accuracy improved from 0.25802 to 0.37029, saving model to /tmp/p01_best_model.h5
# 756/756 [==============================] - 3s 3ms/step - loss: 0.8028 - accuracy: 0.6944 - val_loss: 4.8411 - val_accuracy: 0.3703
# Epoch 5/30
# 743/756 [============================>.] - ETA: 0s - loss: 0.7096 - accuracy: 0.7281
# Epoch 5: val_accuracy did not improve from 0.37029
# 756/756 [==============================] - 3s 3ms/step - loss: 0.7087 - accuracy: 0.7281 - val_loss: 7.9464 - val_accuracy: 0.3190
# Epoch 6/30
# 752/756 [============================>.] - ETA: 0s - loss: 0.6649 - accuracy: 0.7486
# Epoch 6: val_accuracy did not improve from 0.37029
# 756/756 [==============================] - 3s 3ms/step - loss: 0.6646 - accuracy: 0.7487 - val_loss: 8.3985 - val_accuracy: 0.2544
# Epoch 7/30
# 746/756 [============================>.] - ETA: 0s - loss: 0.6379 - accuracy: 0.7580
# Epoch 7: val_accuracy improved from 0.37029 to 0.44717, saving model to /tmp/p01_best_model.h5
# 756/756 [==============================] - 3s 3ms/step - loss: 0.6385 - accuracy: 0.7580 - val_loss: 5.4551 - val_accuracy: 0.4472
# Epoch 8/30
# 739/756 [============================>.] - ETA: 0s - loss: 0.5835 - accuracy: 0.7831
# Epoch 8: val_accuracy did not improve from 0.44717
# 756/756 [==============================] - 3s 3ms/step - loss: 0.5814 - accuracy: 0.7840 - val_loss: 8.3012 - val_accuracy: 0.3344
# Epoch 9/30
# 748/756 [============================>.] - ETA: 0s - loss: 0.5737 - accuracy: 0.7818
# Epoch 9: val_accuracy did not improve from 0.44717
# 756/756 [==============================] - 3s 3ms/step - loss: 0.5751 - accuracy: 0.7816 - val_loss: 7.9327 - val_accuracy: 0.3410
# Epoch 10/30
# 751/756 [============================>.] - ETA: 0s - loss: 0.5729 - accuracy: 0.7870
# Epoch 10: val_accuracy did not improve from 0.44717
# 756/756 [==============================] - 3s 3ms/step - loss: 0.5726 - accuracy: 0.7871 - val_loss: 17.1190 - val_accuracy: 0.3990
# Epoch 11/30
# 739/756 [============================>.] - ETA: 0s - loss: 0.5153 - accuracy: 0.8081
# Epoch 11: val_accuracy did not improve from 0.44717
# 756/756 [==============================] - 3s 3ms/step - loss: 0.5134 - accuracy: 0.8087 - val_loss: 12.4921 - val_accuracy: 0.3880
# Epoch 12/30
# 753/756 [============================>.] - ETA: 0s - loss: 0.5016 - accuracy: 0.8095
# Epoch 12: val_accuracy did not improve from 0.44717
# 756/756 [==============================] - 3s 3ms/step - loss: 0.5018 - accuracy: 0.8094 - val_loss: 13.9667 - val_accuracy: 0.3378
# Epoch 13/30
# 746/756 [============================>.] - ETA: 0s - loss: 0.4926 - accuracy: 0.8146
# Epoch 13: val_accuracy did not improve from 0.44717
# 756/756 [==============================] - 3s 3ms/step - loss: 0.4906 - accuracy: 0.8152 - val_loss: 17.7430 - val_accuracy: 0.3490
# Epoch 14/30
# 755/756 [============================>.] - ETA: 0s - loss: 0.4798 - accuracy: 0.8206
# Epoch 14: val_accuracy did not improve from 0.44717
# 756/756 [==============================] - 3s 3ms/step - loss: 0.4797 - accuracy: 0.8206 - val_loss: 19.8231 - val_accuracy: 0.3534
# Epoch 15/30
# 755/756 [============================>.] - ETA: 0s - loss: 0.4374 - accuracy: 0.8380
# Epoch 15: val_accuracy did not improve from 0.44717
# 756/756 [==============================] - 3s 3ms/step - loss: 0.4378 - accuracy: 0.8378 - val_loss: 14.9898 - val_accuracy: 0.3535
# Epoch 16/30
# 749/756 [============================>.] - ETA: 0s - loss: 0.4322 - accuracy: 0.8428
# Epoch 16: val_accuracy did not improve from 0.44717
# 756/756 [==============================] - 3s 3ms/step - loss: 0.4317 - accuracy: 0.8431 - val_loss: 10.6871 - val_accuracy: 0.3808
# Epoch 17/30
# 744/756 [============================>.] - ETA: 0s - loss: 0.4145 - accuracy: 0.8472
# Epoch 17: val_accuracy improved from 0.44717 to 0.46891, saving model to /tmp/p01_best_model.h5
# 756/756 [==============================] - 3s 3ms/step - loss: 0.4140 - accuracy: 0.8476 - val_loss: 23.9665 - val_accuracy: 0.4689
# Epoch 18/30
# 751/756 [============================>.] - ETA: 0s - loss: 0.4173 - accuracy: 0.8440
# Epoch 18: val_accuracy did not improve from 0.46891
# 756/756 [==============================] - 3s 3ms/step - loss: 0.4182 - accuracy: 0.8438 - val_loss: 16.9183 - val_accuracy: 0.4552
# Epoch 19/30
# 753/756 [============================>.] - ETA: 0s - loss: 0.4008 - accuracy: 0.8521
# Epoch 19: val_accuracy did not improve from 0.46891
# 756/756 [==============================] - 3s 4ms/step - loss: 0.4007 - accuracy: 0.8522 - val_loss: 29.7920 - val_accuracy: 0.3025
# Epoch 20/30
# 753/756 [============================>.] - ETA: 0s - loss: 0.3962 - accuracy: 0.8555
# Epoch 20: val_accuracy improved from 0.46891 to 0.47482, saving model to /tmp/p01_best_model.h5
# 756/756 [==============================] - 3s 4ms/step - loss: 0.3966 - accuracy: 0.8553 - val_loss: 22.9095 - val_accuracy: 0.4748
# Epoch 21/30
# 744/756 [============================>.] - ETA: 0s - loss: 0.3891 - accuracy: 0.8593
# Epoch 21: val_accuracy improved from 0.47482 to 0.50909, saving model to /tmp/p01_best_model.h5
# 756/756 [==============================] - 3s 3ms/step - loss: 0.3883 - accuracy: 0.8596 - val_loss: 34.0598 - val_accuracy: 0.5091
# Epoch 22/30
# 743/756 [============================>.] - ETA: 0s - loss: 0.3974 - accuracy: 0.8529
# Epoch 22: val_accuracy did not improve from 0.50909
# 756/756 [==============================] - 3s 3ms/step - loss: 0.3965 - accuracy: 0.8532 - val_loss: 14.7238 - val_accuracy: 0.4633
# Epoch 23/30
# 756/756 [==============================] - ETA: 0s - loss: 0.3715 - accuracy: 0.8642
# Epoch 23: val_accuracy did not improve from 0.50909
# 756/756 [==============================] - 3s 3ms/step - loss: 0.3715 - accuracy: 0.8642 - val_loss: 21.0018 - val_accuracy: 0.3643
# Epoch 24/30
# 752/756 [============================>.] - ETA: 0s - loss: 0.3539 - accuracy: 0.8721
# Epoch 24: val_accuracy did not improve from 0.50909
# 756/756 [==============================] - 3s 4ms/step - loss: 0.3535 - accuracy: 0.8722 - val_loss: 17.5430 - val_accuracy: 0.3641
# Epoch 25/30
# 748/756 [============================>.] - ETA: 0s - loss: 0.3462 - accuracy: 0.8761
# Epoch 25: val_accuracy did not improve from 0.50909
# 756/756 [==============================] - 3s 4ms/step - loss: 0.3463 - accuracy: 0.8761 - val_loss: 35.5608 - val_accuracy: 0.4846
# Epoch 26/30
# 751/756 [============================>.] - ETA: 0s - loss: 0.3558 - accuracy: 0.8690
# Epoch 26: val_accuracy did not improve from 0.50909
# 756/756 [==============================] - 3s 4ms/step - loss: 0.3556 - accuracy: 0.8690 - val_loss: 36.0815 - val_accuracy: 0.4545
# Epoch 27/30
# 754/756 [============================>.] - ETA: 0s - loss: 0.3549 - accuracy: 0.8682
# Epoch 27: val_accuracy did not improve from 0.50909
# 756/756 [==============================] - 3s 4ms/step - loss: 0.3550 - accuracy: 0.8681 - val_loss: 16.9462 - val_accuracy: 0.4528
# Epoch 28/30
# 748/756 [============================>.] - ETA: 0s - loss: 0.3334 - accuracy: 0.8780
# Epoch 28: val_accuracy did not improve from 0.50909
# 756/756 [==============================] - 3s 4ms/step - loss: 0.3334 - accuracy: 0.8782 - val_loss: 23.4061 - val_accuracy: 0.3883
# Epoch 29/30
# 754/756 [============================>.] - ETA: 0s - loss: 0.3254 - accuracy: 0.8834
# Epoch 29: val_accuracy did not improve from 0.50909
# 756/756 [==============================] - 3s 4ms/step - loss: 0.3254 - accuracy: 0.8834 - val_loss: 33.8205 - val_accuracy: 0.3598
# Epoch 30/30
# 753/756 [============================>.] - ETA: 0s - loss: 0.3338 - accuracy: 0.8816
# Epoch 30: val_accuracy did not improve from 0.50909
# 756/756 [==============================] - 3s 4ms/step - loss: 0.3338 - accuracy: 0.8816 - val_loss: 22.7925 - val_accuracy: 0.4268
# 360/360 [==============================] - 1s 2ms/step - loss: 34.0598 - accuracy: 0.5091
# LOSO user: ['p01' 'p01' 'p01' ... 'p15' 'p15' 'p15']
# Fold Accuracy: 0.5090877413749695 loss: 34.05976486206055
# Epoch 1/30
# 1098/1103 [============================>.] - ETA: 0s - loss: 1.7237 - accuracy: 0.3161
# Epoch 1: val_accuracy improved from -inf to 0.00000, saving model to /tmp/p02_best_model.h5
# 1103/1103 [==============================] - 5s 3ms/step - loss: 1.7228 - accuracy: 0.3167 - val_loss: 3.7263 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 1089/1103 [============================>.] - ETA: 0s - loss: 1.2129 - accuracy: 0.5179
# Epoch 2: val_accuracy improved from 0.00000 to 0.22169, saving model to /tmp/p02_best_model.h5
# 1103/1103 [==============================] - 4s 3ms/step - loss: 1.2114 - accuracy: 0.5188 - val_loss: 2.3470 - val_accuracy: 0.2217
# Epoch 3/30
# 1090/1103 [============================>.] - ETA: 0s - loss: 0.9848 - accuracy: 0.6124
# Epoch 3: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.9843 - accuracy: 0.6123 - val_loss: 8.4588 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 1102/1103 [============================>.] - ETA: 0s - loss: 0.8883 - accuracy: 0.6519
# Epoch 4: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.8883 - accuracy: 0.6518 - val_loss: 16.2683 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 1096/1103 [============================>.] - ETA: 0s - loss: 0.7928 - accuracy: 0.6939
# Epoch 5: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.7929 - accuracy: 0.6939 - val_loss: 9.6430 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 1094/1103 [============================>.] - ETA: 0s - loss: 0.7390 - accuracy: 0.7162
# Epoch 6: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.7382 - accuracy: 0.7165 - val_loss: 12.2481 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 1097/1103 [============================>.] - ETA: 0s - loss: 0.6796 - accuracy: 0.7385
# Epoch 7: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.6793 - accuracy: 0.7387 - val_loss: 26.0550 - val_accuracy: 0.0000e+00
# Epoch 8/30
# 1091/1103 [============================>.] - ETA: 0s - loss: 0.6555 - accuracy: 0.7503
# Epoch 8: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.6550 - accuracy: 0.7505 - val_loss: 5.1973 - val_accuracy: 0.0000e+00
# Epoch 9/30
# 1094/1103 [============================>.] - ETA: 0s - loss: 0.5979 - accuracy: 0.7747
# Epoch 9: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.6005 - accuracy: 0.7744 - val_loss: 13.0058 - val_accuracy: 0.0000e+00
# Epoch 10/30
# 1098/1103 [============================>.] - ETA: 0s - loss: 0.5992 - accuracy: 0.7717
# Epoch 10: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.5990 - accuracy: 0.7716 - val_loss: 12.5635 - val_accuracy: 0.0000e+00
# Epoch 11/30
# 1087/1103 [============================>.] - ETA: 0s - loss: 0.5719 - accuracy: 0.7833
# Epoch 11: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.5720 - accuracy: 0.7831 - val_loss: 8.7966 - val_accuracy: 0.0000e+00
# Epoch 12/30
# 1097/1103 [============================>.] - ETA: 0s - loss: 0.5361 - accuracy: 0.7971
# Epoch 12: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.5358 - accuracy: 0.7972 - val_loss: 11.0108 - val_accuracy: 0.0000e+00
# Epoch 13/30
# 1092/1103 [============================>.] - ETA: 0s - loss: 0.5211 - accuracy: 0.8034
# Epoch 13: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.5216 - accuracy: 0.8029 - val_loss: 17.5570 - val_accuracy: 0.0000e+00
# Epoch 14/30
# 1091/1103 [============================>.] - ETA: 0s - loss: 0.5038 - accuracy: 0.8145
# Epoch 14: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.5030 - accuracy: 0.8150 - val_loss: 8.5316 - val_accuracy: 0.0000e+00
# Epoch 15/30
# 1101/1103 [============================>.] - ETA: 0s - loss: 0.5005 - accuracy: 0.8138
# Epoch 15: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.5005 - accuracy: 0.8139 - val_loss: 10.1972 - val_accuracy: 0.0000e+00
# Epoch 16/30
# 1097/1103 [============================>.] - ETA: 0s - loss: 0.4638 - accuracy: 0.8267
# Epoch 16: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.4632 - accuracy: 0.8269 - val_loss: 13.2302 - val_accuracy: 0.0000e+00
# Epoch 17/30
# 1102/1103 [============================>.] - ETA: 0s - loss: 0.4620 - accuracy: 0.8268
# Epoch 17: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.4620 - accuracy: 0.8268 - val_loss: 13.5822 - val_accuracy: 0.0000e+00
# Epoch 18/30
# 1087/1103 [============================>.] - ETA: 0s - loss: 0.4527 - accuracy: 0.8299
# Epoch 18: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.4533 - accuracy: 0.8297 - val_loss: 8.6252 - val_accuracy: 0.0000e+00
# Epoch 19/30
# 1088/1103 [============================>.] - ETA: 0s - loss: 0.4309 - accuracy: 0.8398
# Epoch 19: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 3s 3ms/step - loss: 0.4314 - accuracy: 0.8397 - val_loss: 15.1355 - val_accuracy: 0.0000e+00
# Epoch 20/30
# 1091/1103 [============================>.] - ETA: 0s - loss: 0.4270 - accuracy: 0.8396
# Epoch 20: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.4266 - accuracy: 0.8398 - val_loss: 11.4612 - val_accuracy: 0.0096
# Epoch 21/30
# 1102/1103 [============================>.] - ETA: 0s - loss: 0.4279 - accuracy: 0.8403
# Epoch 21: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.4280 - accuracy: 0.8403 - val_loss: 2.1072 - val_accuracy: 0.0337
# Epoch 22/30
# 1092/1103 [============================>.] - ETA: 0s - loss: 0.4003 - accuracy: 0.8519
# Epoch 22: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.4005 - accuracy: 0.8520 - val_loss: 14.4562 - val_accuracy: 0.0000e+00
# Epoch 23/30
# 1099/1103 [============================>.] - ETA: 0s - loss: 0.4089 - accuracy: 0.8475
# Epoch 23: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.4087 - accuracy: 0.8476 - val_loss: 12.2951 - val_accuracy: 0.0000e+00
# Epoch 24/30
# 1099/1103 [============================>.] - ETA: 0s - loss: 0.3923 - accuracy: 0.8555
# Epoch 24: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.3921 - accuracy: 0.8556 - val_loss: 13.4790 - val_accuracy: 0.0000e+00
# Epoch 25/30
# 1099/1103 [============================>.] - ETA: 0s - loss: 0.3854 - accuracy: 0.8586
# Epoch 25: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.3855 - accuracy: 0.8587 - val_loss: 12.9958 - val_accuracy: 0.0000e+00
# Epoch 26/30
# 1102/1103 [============================>.] - ETA: 0s - loss: 0.3895 - accuracy: 0.8595
# Epoch 26: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.3895 - accuracy: 0.8595 - val_loss: 22.0323 - val_accuracy: 0.0000e+00
# Epoch 27/30
# 1098/1103 [============================>.] - ETA: 0s - loss: 0.3849 - accuracy: 0.8591
# Epoch 27: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.3844 - accuracy: 0.8593 - val_loss: 8.6531 - val_accuracy: 0.0000e+00
# Epoch 28/30
# 1095/1103 [============================>.] - ETA: 0s - loss: 0.3726 - accuracy: 0.8650
# Epoch 28: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.3726 - accuracy: 0.8649 - val_loss: 30.0920 - val_accuracy: 0.0000e+00
# Epoch 29/30
# 1091/1103 [============================>.] - ETA: 0s - loss: 0.3682 - accuracy: 0.8635
# Epoch 29: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.3681 - accuracy: 0.8635 - val_loss: 18.5911 - val_accuracy: 0.0000e+00
# Epoch 30/30
# 1100/1103 [============================>.] - ETA: 0s - loss: 0.3638 - accuracy: 0.8666
# Epoch 30: val_accuracy did not improve from 0.22169
# 1103/1103 [==============================] - 4s 3ms/step - loss: 0.3643 - accuracy: 0.8666 - val_loss: 14.4532 - val_accuracy: 0.0000e+00
# 13/13 [==============================] - 0s 2ms/step - loss: 2.3470 - accuracy: 0.2217
# LOSO user: ['p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02'
#  'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p02' 'p03' 'p03'
#  'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03'
#  'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03'
#  'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03'
#  'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03'
#  'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03'
#  'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03'
#  'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03'
#  'p03' 'p03' 'p03' 'p03' 'p03' 'p03' 'p03']
# Fold Accuracy: 0.22168675065040588 loss: 2.3470423221588135
# Epoch 1/30
# 1107/1112 [============================>.] - ETA: 0s - loss: 1.6372 - accuracy: 0.3515
# Epoch 1: val_accuracy improved from -inf to 0.00000, saving model to /tmp/p10_best_model.h5
# 1112/1112 [==============================] - 5s 3ms/step - loss: 1.6350 - accuracy: 0.3523 - val_loss: 5.6608 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 1098/1112 [============================>.] - ETA: 0s - loss: 1.0857 - accuracy: 0.5704
# Epoch 2: val_accuracy did not improve from 0.00000
# 1112/1112 [==============================] - 3s 3ms/step - loss: 1.0843 - accuracy: 0.5710 - val_loss: 4.7814 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 1109/1112 [============================>.] - ETA: 0s - loss: 0.9195 - accuracy: 0.6449
# Epoch 3: val_accuracy did not improve from 0.00000
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.9192 - accuracy: 0.6450 - val_loss: 5.7549 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 1105/1112 [============================>.] - ETA: 0s - loss: 0.8326 - accuracy: 0.6801
# Epoch 4: val_accuracy did not improve from 0.00000
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.8323 - accuracy: 0.6802 - val_loss: 9.0136 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 1096/1112 [============================>.] - ETA: 0s - loss: 0.7582 - accuracy: 0.7124
# Epoch 5: val_accuracy did not improve from 0.00000
# 1112/1112 [==============================] - 4s 3ms/step - loss: 0.7569 - accuracy: 0.7130 - val_loss: 2.6174 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 1099/1112 [============================>.] - ETA: 0s - loss: 0.7040 - accuracy: 0.7326
# Epoch 6: val_accuracy did not improve from 0.00000
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.7043 - accuracy: 0.7327 - val_loss: 2.8696 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 1104/1112 [============================>.] - ETA: 0s - loss: 0.6661 - accuracy: 0.7481
# Epoch 7: val_accuracy did not improve from 0.00000
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.6658 - accuracy: 0.7481 - val_loss: 4.8659 - val_accuracy: 0.0000e+00
# Epoch 8/30
# 1098/1112 [============================>.] - ETA: 0s - loss: 0.6418 - accuracy: 0.7566
# Epoch 8: val_accuracy did not improve from 0.00000
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.6418 - accuracy: 0.7569 - val_loss: 7.5041 - val_accuracy: 0.0000e+00
# Epoch 9/30
# 1110/1112 [============================>.] - ETA: 0s - loss: 0.6111 - accuracy: 0.7681
# Epoch 9: val_accuracy did not improve from 0.00000
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.6110 - accuracy: 0.7682 - val_loss: 4.8510 - val_accuracy: 0.0000e+00
# Epoch 10/30
# 1101/1112 [============================>.] - ETA: 0s - loss: 0.5998 - accuracy: 0.7745
# Epoch 10: val_accuracy did not improve from 0.00000
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.6000 - accuracy: 0.7745 - val_loss: 7.2687 - val_accuracy: 0.0000e+00
# Epoch 11/30
# 1110/1112 [============================>.] - ETA: 0s - loss: 0.5608 - accuracy: 0.7889
# Epoch 11: val_accuracy did not improve from 0.00000
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.5609 - accuracy: 0.7888 - val_loss: 4.9625 - val_accuracy: 0.0000e+00
# Epoch 12/30
# 1104/1112 [============================>.] - ETA: 0s - loss: 0.5498 - accuracy: 0.7939
# Epoch 12: val_accuracy did not improve from 0.00000
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.5496 - accuracy: 0.7941 - val_loss: 8.9100 - val_accuracy: 0.0000e+00
# Epoch 13/30
# 1098/1112 [============================>.] - ETA: 0s - loss: 0.5193 - accuracy: 0.8072
# Epoch 13: val_accuracy did not improve from 0.00000
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.5201 - accuracy: 0.8069 - val_loss: 13.8757 - val_accuracy: 0.0000e+00
# Epoch 14/30
# 1103/1112 [============================>.] - ETA: 0s - loss: 0.5008 - accuracy: 0.8150
# Epoch 14: val_accuracy improved from 0.00000 to 0.26923, saving model to /tmp/p10_best_model.h5
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.5012 - accuracy: 0.8150 - val_loss: 1.2720 - val_accuracy: 0.2692
# Epoch 15/30
# 1106/1112 [============================>.] - ETA: 0s - loss: 0.4985 - accuracy: 0.8179
# Epoch 15: val_accuracy did not improve from 0.26923
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.4987 - accuracy: 0.8177 - val_loss: 3.7801 - val_accuracy: 0.0000e+00
# Epoch 16/30
# 1097/1112 [============================>.] - ETA: 0s - loss: 0.4836 - accuracy: 0.8202
# Epoch 16: val_accuracy did not improve from 0.26923
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.4835 - accuracy: 0.8202 - val_loss: 5.2620 - val_accuracy: 0.0000e+00
# Epoch 17/30
# 1108/1112 [============================>.] - ETA: 0s - loss: 0.4639 - accuracy: 0.8302
# Epoch 17: val_accuracy did not improve from 0.26923
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.4634 - accuracy: 0.8304 - val_loss: 12.0176 - val_accuracy: 0.0000e+00
# Epoch 18/30
# 1096/1112 [============================>.] - ETA: 0s - loss: 0.4710 - accuracy: 0.8280
# Epoch 18: val_accuracy did not improve from 0.26923
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.4699 - accuracy: 0.8283 - val_loss: 17.9144 - val_accuracy: 0.0000e+00
# Epoch 19/30
# 1099/1112 [============================>.] - ETA: 0s - loss: 0.4481 - accuracy: 0.8378
# Epoch 19: val_accuracy did not improve from 0.26923
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.4486 - accuracy: 0.8376 - val_loss: 7.4520 - val_accuracy: 0.0000e+00
# Epoch 20/30
# 1098/1112 [============================>.] - ETA: 0s - loss: 0.4399 - accuracy: 0.8393
# Epoch 20: val_accuracy improved from 0.26923 to 0.97115, saving model to /tmp/p10_best_model.h5
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.4417 - accuracy: 0.8387 - val_loss: 0.1036 - val_accuracy: 0.9712
# Epoch 21/30
# 1109/1112 [============================>.] - ETA: 0s - loss: 0.4351 - accuracy: 0.8414
# Epoch 21: val_accuracy did not improve from 0.97115
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.4351 - accuracy: 0.8415 - val_loss: 13.6959 - val_accuracy: 0.0000e+00
# Epoch 22/30
# 1099/1112 [============================>.] - ETA: 0s - loss: 0.4306 - accuracy: 0.8425
# Epoch 22: val_accuracy did not improve from 0.97115
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.4308 - accuracy: 0.8425 - val_loss: 6.9702 - val_accuracy: 0.0000e+00
# Epoch 23/30
# 1103/1112 [============================>.] - ETA: 0s - loss: 0.4279 - accuracy: 0.8458
# Epoch 23: val_accuracy did not improve from 0.97115
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.4279 - accuracy: 0.8462 - val_loss: 11.4050 - val_accuracy: 0.0000e+00
# Epoch 24/30
# 1101/1112 [============================>.] - ETA: 0s - loss: 0.4360 - accuracy: 0.8424
# Epoch 24: val_accuracy did not improve from 0.97115
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.4370 - accuracy: 0.8418 - val_loss: 7.1881 - val_accuracy: 0.0000e+00
# Epoch 25/30
# 1112/1112 [==============================] - ETA: 0s - loss: 0.4016 - accuracy: 0.8543
# Epoch 25: val_accuracy did not improve from 0.97115
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.4016 - accuracy: 0.8543 - val_loss: 8.9915 - val_accuracy: 0.0000e+00
# Epoch 26/30
# 1106/1112 [============================>.] - ETA: 0s - loss: 0.3927 - accuracy: 0.8592
# Epoch 26: val_accuracy did not improve from 0.97115
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.3932 - accuracy: 0.8590 - val_loss: 10.6790 - val_accuracy: 0.0000e+00
# Epoch 27/30
# 1096/1112 [============================>.] - ETA: 0s - loss: 0.3995 - accuracy: 0.8566
# Epoch 27: val_accuracy did not improve from 0.97115
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.3987 - accuracy: 0.8566 - val_loss: 10.3511 - val_accuracy: 0.0000e+00
# Epoch 28/30
# 1099/1112 [============================>.] - ETA: 0s - loss: 0.3913 - accuracy: 0.8590
# Epoch 28: val_accuracy did not improve from 0.97115
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.3912 - accuracy: 0.8591 - val_loss: 7.9232 - val_accuracy: 0.0000e+00
# Epoch 29/30
# 1112/1112 [==============================] - ETA: 0s - loss: 0.3930 - accuracy: 0.8587
# Epoch 29: val_accuracy did not improve from 0.97115
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.3930 - accuracy: 0.8587 - val_loss: 8.4136 - val_accuracy: 0.0000e+00
# Epoch 30/30
# 1099/1112 [============================>.] - ETA: 0s - loss: 0.3750 - accuracy: 0.8645
# Epoch 30: val_accuracy did not improve from 0.97115
# 1112/1112 [==============================] - 3s 3ms/step - loss: 0.3757 - accuracy: 0.8641 - val_loss: 12.5967 - val_accuracy: 0.0000e+00
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1036 - accuracy: 0.9712
# LOSO user: ['p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10'
#  'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10'
#  'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10'
#  'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10'
#  'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10'
#  'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10'
#  'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10'
#  'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10'
#  'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10' 'p10']
# Fold Accuracy: 0.9711538553237915 loss: 0.1035885363817215
# Epoch 1/30
# 1096/1111 [============================>.] - ETA: 0s - loss: 1.6914 - accuracy: 0.3334
# Epoch 1: val_accuracy improved from -inf to 0.97656, saving model to /tmp/p12_best_model.h5
# 1111/1111 [==============================] - 4s 3ms/step - loss: 1.6866 - accuracy: 0.3351 - val_loss: 0.5785 - val_accuracy: 0.9766
# Epoch 2/30
# 1102/1111 [============================>.] - ETA: 0s - loss: 1.1333 - accuracy: 0.5634
# Epoch 2: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 1.1331 - accuracy: 0.5637 - val_loss: 11.9166 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 1092/1111 [============================>.] - ETA: 0s - loss: 0.9722 - accuracy: 0.6263
# Epoch 3: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.9710 - accuracy: 0.6267 - val_loss: 3.6077 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 1105/1111 [============================>.] - ETA: 0s - loss: 0.8690 - accuracy: 0.6650
# Epoch 4: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.8683 - accuracy: 0.6653 - val_loss: 3.3125 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 1105/1111 [============================>.] - ETA: 0s - loss: 0.7690 - accuracy: 0.7073
# Epoch 5: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.7692 - accuracy: 0.7071 - val_loss: 4.6232 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 1097/1111 [============================>.] - ETA: 0s - loss: 0.7237 - accuracy: 0.7287
# Epoch 6: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.7238 - accuracy: 0.7285 - val_loss: 4.8848 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 1093/1111 [============================>.] - ETA: 0s - loss: 0.6729 - accuracy: 0.7477
# Epoch 7: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.6716 - accuracy: 0.7483 - val_loss: 4.5372 - val_accuracy: 0.0469
# Epoch 8/30
# 1107/1111 [============================>.] - ETA: 0s - loss: 0.6313 - accuracy: 0.7619
# Epoch 8: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.6313 - accuracy: 0.7618 - val_loss: 3.3422 - val_accuracy: 0.0078
# Epoch 9/30
# 1092/1111 [============================>.] - ETA: 0s - loss: 0.6072 - accuracy: 0.7713
# Epoch 9: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.6063 - accuracy: 0.7717 - val_loss: 4.4766 - val_accuracy: 0.0000e+00
# Epoch 10/30
# 1091/1111 [============================>.] - ETA: 0s - loss: 0.5655 - accuracy: 0.7874
# Epoch 10: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.5652 - accuracy: 0.7874 - val_loss: 7.3199 - val_accuracy: 0.0000e+00
# Epoch 11/30
# 1110/1111 [============================>.] - ETA: 0s - loss: 0.5513 - accuracy: 0.7919
# Epoch 11: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.5513 - accuracy: 0.7920 - val_loss: 3.8469 - val_accuracy: 0.0391
# Epoch 12/30
# 1099/1111 [============================>.] - ETA: 0s - loss: 0.5356 - accuracy: 0.7972
# Epoch 12: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 4s 3ms/step - loss: 0.5352 - accuracy: 0.7973 - val_loss: 4.2969 - val_accuracy: 0.0000e+00
# Epoch 13/30
# 1104/1111 [============================>.] - ETA: 0s - loss: 0.5050 - accuracy: 0.8129
# Epoch 13: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.5048 - accuracy: 0.8130 - val_loss: 8.0297 - val_accuracy: 0.0000e+00
# Epoch 14/30
# 1104/1111 [============================>.] - ETA: 0s - loss: 0.4996 - accuracy: 0.8149
# Epoch 14: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.5005 - accuracy: 0.8146 - val_loss: 3.3296 - val_accuracy: 0.0000e+00
# Epoch 15/30
# 1103/1111 [============================>.] - ETA: 0s - loss: 0.4886 - accuracy: 0.8181
# Epoch 15: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.4886 - accuracy: 0.8182 - val_loss: 4.6237 - val_accuracy: 0.0000e+00
# Epoch 16/30
# 1104/1111 [============================>.] - ETA: 0s - loss: 0.4649 - accuracy: 0.8280
# Epoch 16: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.4652 - accuracy: 0.8276 - val_loss: 2.2466 - val_accuracy: 0.4922
# Epoch 17/30
# 1105/1111 [============================>.] - ETA: 0s - loss: 0.4610 - accuracy: 0.8289
# Epoch 17: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.4606 - accuracy: 0.8291 - val_loss: 0.7162 - val_accuracy: 0.7344
# Epoch 18/30
# 1099/1111 [============================>.] - ETA: 0s - loss: 0.4698 - accuracy: 0.8275
# Epoch 18: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.4714 - accuracy: 0.8269 - val_loss: 4.6838 - val_accuracy: 0.0000e+00
# Epoch 19/30
# 1105/1111 [============================>.] - ETA: 0s - loss: 0.4614 - accuracy: 0.8303
# Epoch 19: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.4612 - accuracy: 0.8303 - val_loss: 6.2768 - val_accuracy: 0.0312
# Epoch 20/30
# 1110/1111 [============================>.] - ETA: 0s - loss: 0.4619 - accuracy: 0.8334
# Epoch 20: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.4619 - accuracy: 0.8334 - val_loss: 7.1961 - val_accuracy: 0.0000e+00
# Epoch 21/30
# 1106/1111 [============================>.] - ETA: 0s - loss: 0.4295 - accuracy: 0.8426
# Epoch 21: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.4296 - accuracy: 0.8427 - val_loss: 12.4467 - val_accuracy: 0.0000e+00
# Epoch 22/30
# 1107/1111 [============================>.] - ETA: 0s - loss: 0.4192 - accuracy: 0.8462
# Epoch 22: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.4198 - accuracy: 0.8463 - val_loss: 4.4545 - val_accuracy: 0.0312
# Epoch 23/30
# 1110/1111 [============================>.] - ETA: 0s - loss: 0.4114 - accuracy: 0.8501
# Epoch 23: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.4115 - accuracy: 0.8500 - val_loss: 8.3461 - val_accuracy: 0.0156
# Epoch 24/30
# 1110/1111 [============================>.] - ETA: 0s - loss: 0.4043 - accuracy: 0.8514
# Epoch 24: val_accuracy did not improve from 0.97656
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.4043 - accuracy: 0.8514 - val_loss: 9.0728 - val_accuracy: 0.0859
# Epoch 25/30
# 1108/1111 [============================>.] - ETA: 0s - loss: 0.3880 - accuracy: 0.8605
# Epoch 25: val_accuracy improved from 0.97656 to 0.99219, saving model to /tmp/p12_best_model.h5
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.3878 - accuracy: 0.8605 - val_loss: 0.0464 - val_accuracy: 0.9922
# Epoch 26/30
# 1096/1111 [============================>.] - ETA: 0s - loss: 0.3906 - accuracy: 0.8564
# Epoch 26: val_accuracy did not improve from 0.99219
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.3911 - accuracy: 0.8563 - val_loss: 8.5319 - val_accuracy: 0.0000e+00
# Epoch 27/30
# 1094/1111 [============================>.] - ETA: 0s - loss: 0.3800 - accuracy: 0.8608
# Epoch 27: val_accuracy did not improve from 0.99219
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.3812 - accuracy: 0.8601 - val_loss: 4.8710 - val_accuracy: 0.0000e+00
# Epoch 28/30
# 1099/1111 [============================>.] - ETA: 0s - loss: 0.3752 - accuracy: 0.8651
# Epoch 28: val_accuracy did not improve from 0.99219
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.3753 - accuracy: 0.8650 - val_loss: 6.2511 - val_accuracy: 0.0859
# Epoch 29/30
# 1098/1111 [============================>.] - ETA: 0s - loss: 0.4366 - accuracy: 0.8417
# Epoch 29: val_accuracy did not improve from 0.99219
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.4359 - accuracy: 0.8422 - val_loss: 9.2735 - val_accuracy: 0.0000e+00
# Epoch 30/30
# 1101/1111 [============================>.] - ETA: 0s - loss: 0.3968 - accuracy: 0.8581
# Epoch 30: val_accuracy did not improve from 0.99219
# 1111/1111 [==============================] - 3s 3ms/step - loss: 0.3972 - accuracy: 0.8580 - val_loss: 11.2170 - val_accuracy: 0.0000e+00
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0464 - accuracy: 0.9922
# LOSO user: ['p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12'
#  'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12'
#  'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12'
#  'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12'
#  'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12'
#  'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12'
#  'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12'
#  'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12'
#  'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12'
#  'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12'
#  'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12' 'p12']
# Fold Accuracy: 0.9921875 loss: 0.046397916972637177
# Average LOSO Accuracy: 0.6192142417033514
# /export/hda3/borglet/remote_hdd_fs_dirs/0.colab_kernel_deepmind_gpu_py3_cadyxu.kernel.cadyxu.3741417284830.14b334fb3717c109/mount/server/dm_notebook3.par/google3/third_party/py/tf_keras/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
